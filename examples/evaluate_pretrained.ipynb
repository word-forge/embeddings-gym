# %% [markdown]
# # Evaluate some pretrained embeddings against implemented evaluations

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('/notebook')

import embegym
import patoolib
import gensim
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# add more pretrained models from URLS:
# http://vsmlib.readthedocs.io/en/latest/tutorial/getting_vectors.html#pre-trained-vsms
# https://github.com/3Top/word2vec-api

# embegym.utils.io.download_if_not_exists('https://s3-us-west-1.amazonaws.com/fasttext-vectors/wiki.en.zip',
#                                         './models/fasttext-wiki.en.zip')
# patoolib.extract_archive('./models/fasttext-wiki.en.zip', outdir='./models/fasttext-wiki.en')
# fasttext_wiki = embegym.models.gensim_wrappers.import_pretrained_fasttext('./models/fasttext-wiki.en/wiki.en',
#                                                                           './models/fasttext-wiki.en/wiki.en.gensim')
# del fasttext_wiki

# embegym.utils.io.download_if_not_exists('http://nlp.stanford.edu/data/glove.840B.300d.zip',
#                                         './models/glove.840B.300d.zip')
# patoolib.extract_archive('./models/glove.840B.300d.zip',
#                          outdir='./models/glove.840B.300d')
# gensim.scripts.glove2word2vec.glove2word2vec('./models/glove.840B.300d/glove.840B.300d.txt',
#                                              './models/glove.840B.300d/glove.840B.300d.w2v')
# glove_840b_300 = embegym.models.gensim_wrappers.import_pretrained_word2vec('./models/glove.840B.300d/glove.840B.300d.w2v',
#                                                                            './models/glove.840B.300d/glove.840B.300d.gensim',
#                                                                            binary=False)
# del glove_840b_300

# %%
fasttext_wiki = embegym.models.gensim_wrappers.GensimKeyedVectors.load('./models/fasttext-wiki.en/wiki.en.gensim', mmap='r')
glove_840b_300 = embegym.models.gensim_wrappers.GensimKeyedVectors.load('./models/glove.840B.300d/glove.840B.300d.gensim', mmap='r')

# %%
evaluation = embegym.evaluation.make_evaluation()
eval_result = evaluation(fasttext_wiki=fasttext_wiki,
                         glove_840b_300=glove_840b_300)
# Out:
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /root/.pyenv/versions/3.6.0/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
eval_result.transpose().sort_index()
# Out:
#                                                  fasttext_wiki  glove_840b_300
# 20ng_lstm        test f1                              0.577859        0.607911
#                  test precision                       0.608527        0.629225
#                  test recall                          0.580115        0.604347
#                  train f1                             0.694827        0.815431
#                  train precision                      0.721083        0.831354
#                  train recall                         0.696900        0.812822
# 20ng_mean_logreg test f1                              0.565153        0.634641
#                  test precision                       0.567864        0.640616
#                  test recall                          0.582629        0.639360
#                  train f1                             0.602508        0.734086
#                  train precision                      0.656008        0.747376
#                  train recall                         0.615970        0.735048
# GoogleAnalogies  capital-common-countries @5          0.001976        0.019763
#                  capital-world @1                          NaN        0.001300
#                  capital-world @5                     0.002653        0.022875
#                  city-in-state @5                     0.012161        0.002027
#                  family @5                            0.065217        0.094862
#                  gram1-adjective-to-adverb @1         0.010081             NaN
#                  gram1-adjective-to-adverb @5         0.029234        0.015121
#                  gram2-opposite @1                    0.004926             NaN
#                  gram2-opposite @5                    0.035714             NaN
#                  gram3-comparative @1                 0.000751             NaN
#                  gram3-comparative @5                 0.021021        0.011261
#                  gram4-superlative @5                 0.004456             NaN
#                  gram5-present-participle @1          0.015152        0.003788
#                  gram5-present-participle @5          0.150568        0.330492
#                  gram6-nationality-adjective @5       0.006254        0.003752
#                  gram7-past-tense @1                  0.003205        0.000641
#                  gram7-past-tense @5                  0.068590        0.096154
#                  gram8-plural @1                      0.019520        0.006006
#                  gram8-plural @5                      0.175676        0.335586
#                  micro-mean @1                        0.003320        0.001000
#                  micro-mean @5                        0.036254        0.062955
#                  morphological @1                     0.011905        0.003293
#                  morphological @5                     0.126646        0.239615
#                  semantic @1                          0.000000        0.000610
#                  semantic @5                          0.008569        0.018433
#                  syntactic @1                         0.002561        0.000000
#                  syntactic @5                         0.017244        0.006146
# SimLex999        Assoc(USF)                           0.350367        0.409907
#                  SD(SimLex)                          -0.008679        0.001177
#                  SimLex999                            0.380338        0.408285
#                  conc(w1)                            -0.078251       -0.053493
#                  conc(w2)                            -0.075687       -0.047709
